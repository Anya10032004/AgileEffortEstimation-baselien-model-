# %%
import pandas as pd

lala = pd.read_csv('C:\\Users\\Anya\\OneDrive\\Documents\\GitHub\\AgileEffortEstimation-baselien-model-\\datasets\\Choet_Dataset\\APSTUD_deep-se.csv')

lala.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829 entries, 0 to 828
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   issuekey     829 non-null    object
#  1   title        829 non-null    object
#  2   description  771 non-null    object
#  3   storypoint   829 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 26.0+ KB
